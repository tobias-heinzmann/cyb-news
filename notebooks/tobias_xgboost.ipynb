# %%
import os
import string
from datetime import datetime
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import make_pipeline

import nltk
from nltk.tokenize import word_tokenize

from gensim.models import Word2Vec

from tensorflow.config.experimental import list_physical_devices, set_memory_growth
from tensorflow.keras.initializers import GlorotUniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, Embedding, Dropout, SpatialDropout1D, SimpleRNN
from tensorflow.keras.regularizers import l2

import optuna

from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

from cybnews.data import get_data, welf_join_text

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

print("Num GPUs Available: ", len(list_physical_devices('GPU')))

gpus = list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  1

# %%
df = pd.read_csv('/home/tober/devel/lewagon/project/cyb-news/data/unified_data.csv', index_col=0)
df.head()
# Out:
#                                     all_text_cleaned  label
# 0  culture war history conversation andrew hartma...      1
# 1  blood collection chair market growth top manuf...      1
# 2  terrorist attack archive ⋆ dc gazette terroris...      1
# 3  christian life coach star tim storey talk past...      0
# 4  israel takeover internet israel takeover inter...      1

# %%
#data = df.sample(frac=0.5, random_state=42)

# %%
# {'colsample_bytree': 0.6, 'learning_rate': 0.2, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.7}
# Text preprocessing and feature extraction
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['all_text_cleaned'])

X_train, X_test, y_train, y_test = train_test_split(
    X,
    df['label'],
    test_size=0.2,
    random_state=42
)

model = XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss',
    colsample_bytree=0.6,
    learning_rate=0.2,
    max_depth=6,
    n_estimators=300,
    subsample=0.7,
    n_jobs=28
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9561749128019635
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96     15213
#            1       0.97      0.94      0.96     15751
#
#     accuracy                           0.96     30964
#    macro avg       0.96      0.96      0.96     30964
# weighted avg       0.96      0.96      0.96     30964

# %%
model.save_model('xgboost')

# %%
loaded_model = XGBClassifier()
loaded_model.load_model('xgboost')
y_pred = loaded_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9561749128019635
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96     15213
#            1       0.97      0.94      0.96     15751
#
#     accuracy                           0.96     30964
#    macro avg       0.96      0.96      0.96     30964
# weighted avg       0.96      0.96      0.96     30964

# %%
# Text preprocessing and feature extraction
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(data['all_text_cleaned'])

X_train, X_test, y_train, y_test = train_test_split(X, data['label'], test_size=0.2, random_state=42)

#model = XGBClassifier(tree_method='gpu_hist', use_label_encoder=False, eval_metric='logloss')
model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')


# param_grid = {
#     'n_estimators': [300, 320, 340],#, 100, 150, 200, 250],
#     'max_depth': [5, 6, 7],
#     'learning_rate': [0.1, 0.2],
#     # 'subsample': [0.6, 0.7, 0.8, 0.9],
#     # 'colsample_bytree': [0.7, 0.8, 0.9, 1.0]
# }

# {'colsample_bytree': 0.6, 'learning_rate': 0.2, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.7}

param_grid = {
    'n_estimators': [260, 280, 300, 320, 340],
    'max_depth': [5, 6, 7],
    'learning_rate': [0.15, 0.2, 0.25],
    'subsample': [0.4, 0.5, 0.6, 0.7],
    'colsample_bytree': [0.4, 0.5, 0.6, 0.7]
}

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid, 
    scoring='accuracy',
    cv=3,
    verbose=3,
    n_jobs=28,
    error_score="raise",
)

grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

print("Best Parameters:", grid_search.best_params_)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 720 candidates, totalling 2160 fits
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.5;, score=0.920 total time=  33.6s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.4;, score=0.921 total time=  34.7s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.4;, score=0.922 total time=  36.2s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.4;, score=0.918 total time=  36.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.4;, score=0.920 total time=  36.8s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.4;, score=0.922 total time=  36.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.5;, score=0.921 total time=  37.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.4;, score=0.919 total time=  39.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.5;, score=0.920 total time=  40.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.6;, score=0.922 total time=  41.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.6;, score=0.930 total time=  41.6s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.5;, score=0.923 total time=  41.6s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.6;, score=0.922 total time=  41.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.5;, score=0.919 total time=  41.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.4;, score=0.923 total time=  41.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.4;, score=0.921 total time=  42.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.5;, score=0.926 total time=  42.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.4;, score=0.919 total time=  42.3s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.7;, score=0.920 total time=  43.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.5;, score=0.920 total time=  43.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.6;, score=0.928 total time=  44.6s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.6;, score=0.922 total time=  45.0s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.7;, score=0.921 total time=  45.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.7;, score=0.922 total time=  45.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.7;, score=0.923 total time=  47.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.6;, score=0.923 total time=  49.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=260, subsample=0.7;, score=0.927 total time=  50.0s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=280, subsample=0.7;, score=0.927 total time=  53.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.5;, score=0.925 total time=  36.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.6;, score=0.923 total time=  44.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.5;, score=0.919 total time=  47.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.4;, score=0.918 total time=  44.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.4;, score=0.924 total time=  39.3s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.4;, score=0.919 total time=  43.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.4;, score=0.922 total time=  40.8s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.4;, score=0.925 total time=  45.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.6;, score=0.923 total time=  52.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.6;, score=0.929 total time=  52.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.5;, score=0.921 total time=  41.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.5;, score=0.918 total time=  43.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.5;, score=0.920 total time=  48.1s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.4;, score=0.919 total time=  46.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.7;, score=0.924 total time=  48.0s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.5;, score=0.920 total time=  50.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.7;, score=0.922 total time=  55.6s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.5;, score=0.925 total time=  50.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.7;, score=0.923 total time=  50.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.7;, score=0.923 total time=  56.0s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=300, subsample=0.7;, score=0.926 total time=  55.7s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.6;, score=0.928 total time=  53.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.6;, score=0.922 total time=  55.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.6;, score=0.923 total time=  55.7s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=320, subsample=0.7;, score=0.925 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.5;, score=0.928 total time=  54.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.6;, score=0.921 total time=  59.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.6;, score=0.926 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.4;, score=0.918 total time=  35.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.5;, score=0.918 total time=  38.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.6;, score=0.930 total time=  35.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.4;, score=0.920 total time=  42.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.6;, score=0.926 total time=  38.8s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.4;, score=0.925 total time=  44.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.6;, score=0.929 total time=  59.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.4;, score=0.919 total time=  41.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.5;, score=0.927 total time=  49.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.5;, score=0.920 total time=  49.6s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.4;, score=0.918 total time=  46.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.4;, score=0.928 total time=  46.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.7;, score=0.923 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.7;, score=0.923 total time=  59.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=5, n_estimators=340, subsample=0.7;, score=0.927 total time=  57.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.6;, score=0.924 total time=  54.6s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.5;, score=0.919 total time=  52.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.5;, score=0.922 total time=  51.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.7;, score=0.928 total time=  57.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.7;, score=0.926 total time=  58.2s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.7;, score=0.928 total time=  45.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.5;, score=0.926 total time=  53.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=260, subsample=0.7;, score=0.931 total time=  57.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.6;, score=0.927 total time=  57.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.6;, score=0.924 total time=  58.0s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.6;, score=0.930 total time=  55.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.4;, score=0.920 total time=  42.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.4;, score=0.918 total time=  42.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.4;, score=0.926 total time=  43.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.7;, score=0.926 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=280, subsample=0.7;, score=0.932 total time=  60.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.5;, score=0.922 total time=  46.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.6;, score=0.928 total time=  45.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.5;, score=0.917 total time=  55.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.5;, score=0.926 total time=  56.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.6;, score=0.924 total time=  53.2s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.4;, score=0.919 total time=  46.7s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.4;, score=0.927 total time=  48.6s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.7;, score=0.932 total time=  51.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.4;, score=0.922 total time=  52.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.5;, score=0.918 total time=  52.0s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.6;, score=0.930 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.7;, score=0.928 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=300, subsample=0.7;, score=0.927 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.5;, score=0.926 total time=  59.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.5;, score=0.922 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.6;, score=0.926 total time=  58.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.4;, score=0.921 total time=  52.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.6;, score=0.930 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.7;, score=0.932 total time=  57.7s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.6;, score=0.923 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.4;, score=0.925 total time=  55.2s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.4;, score=0.920 total time=  58.2s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.7;, score=0.926 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=320, subsample=0.7;, score=0.928 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.5;, score=0.927 total time=  50.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.4;, score=0.916 total time=  36.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.5;, score=0.917 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.4;, score=0.919 total time=  40.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.5;, score=0.924 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.4;, score=0.926 total time=  49.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.6;, score=0.930 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.6;, score=0.924 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.6;, score=0.928 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.5;, score=0.924 total time=  53.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.7;, score=0.933 total time=  59.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.7;, score=0.928 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.5;, score=0.924 total time=  55.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.5;, score=0.926 total time=  55.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=6, n_estimators=340, subsample=0.7;, score=0.926 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.6;, score=0.924 total time=  57.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.4;, score=0.915 total time=  51.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.6;, score=0.927 total time=  57.3s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.4;, score=0.920 total time=  52.1s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.4;, score=0.924 total time=  51.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.6;, score=0.923 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.7;, score=0.930 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.7;, score=0.928 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=260, subsample=0.7;, score=0.925 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.5;, score=0.923 total time=  56.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.5;, score=0.924 total time=  59.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.5;, score=0.927 total time=  58.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.6;, score=0.923 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.7;, score=0.929 total time=  55.6s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.6;, score=0.922 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.6;, score=0.928 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.4;, score=0.923 total time=  46.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.4;, score=0.920 total time=  47.4s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.4;, score=0.917 total time=  55.1s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.6;, score=0.925 total time=  50.7s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.7;, score=0.925 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=280, subsample=0.7;, score=0.931 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.5;, score=0.925 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.5;, score=0.925 total time=  59.8s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.5;, score=0.927 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.4;, score=0.922 total time=  52.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.4;, score=0.923 total time=  51.6s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.4;, score=0.919 total time=  54.2s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.6;, score=0.924 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.6;, score=0.928 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.7;, score=0.930 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.7;, score=0.930 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.5;, score=0.923 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.5;, score=0.926 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=300, subsample=0.7;, score=0.926 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.5;, score=0.927 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.4;, score=0.916 total time=  52.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.6;, score=0.928 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.6;, score=0.924 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.6;, score=0.923 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.4;, score=0.922 total time=  59.6s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.4;, score=0.925 total time=  58.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.5;, score=0.922 total time=  59.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.5;, score=0.930 total time=  52.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.4;, score=0.918 total time=  36.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.4;, score=0.924 total time=  32.2s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.4;, score=0.919 total time=  37.1s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.7;, score=0.930 total time= 1.3min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.7;, score=0.923 total time= 1.3min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=320, subsample=0.7;, score=0.930 total time= 1.3min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.5;, score=0.921 total time=  41.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.6;, score=0.924 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.5;, score=0.927 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.6;, score=0.926 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.5;, score=0.919 total time=  42.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.5;, score=0.927 total time=  41.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.6;, score=0.921 total time=  44.0s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.6;, score=0.928 total time=  43.6s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.6;, score=0.920 total time=  45.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.7;, score=0.929 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.6;, score=0.925 total time= 1.3min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.5;, score=0.920 total time=  32.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.4;, score=0.915 total time=  39.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.7;, score=0.931 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.4;, score=0.918 total time=  39.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.7;, score=0.924 total time=  46.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.5;, score=0.925 total time=  32.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.4;, score=0.922 total time=  39.0s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.7;, score=0.922 total time=  49.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.5;, score=0.922 total time=  42.7s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.15, max_depth=7, n_estimators=340, subsample=0.7;, score=0.925 total time= 1.4min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=260, subsample=0.7;, score=0.927 total time=  49.2s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.6;, score=0.922 total time=  45.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.6;, score=0.933 total time=  45.2s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.6;, score=0.919 total time=  48.2s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.7;, score=0.922 total time=  52.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.4;, score=0.916 total time=  42.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.4;, score=0.919 total time=  42.4s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.5;, score=0.923 total time=  38.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.4;, score=0.922 total time=  42.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.7;, score=0.923 total time=  52.7s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=280, subsample=0.7;, score=0.929 total time=  51.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.5;, score=0.921 total time=  48.3s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6;, score=0.922 total time=  43.8s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.5;, score=0.930 total time=  47.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.4;, score=0.924 total time=  38.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.4;, score=0.919 total time=  38.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.5;, score=0.920 total time=  39.4s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6;, score=0.922 total time=  51.2s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.4;, score=0.917 total time=  44.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.5;, score=0.929 total time=  43.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.6;, score=0.932 total time=  50.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.5;, score=0.922 total time=  50.6s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.7;, score=0.926 total time=  55.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.7;, score=0.923 total time=  56.1s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=300, subsample=0.7;, score=0.929 total time=  55.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.6;, score=0.932 total time=  50.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.6;, score=0.923 total time=  55.3s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.6;, score=0.922 total time=  52.1s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.4;, score=0.919 total time=  46.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.4;, score=0.920 total time=  42.6s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.7;, score=0.925 total time=  57.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.7;, score=0.929 total time=  52.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=320, subsample=0.7;, score=0.922 total time=  56.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.4;, score=0.924 total time=  47.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.5;, score=0.921 total time=  46.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.5;, score=0.922 total time=  52.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.4;, score=0.917 total time=  37.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.4;, score=0.917 total time=  39.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.5;, score=0.929 total time=  53.6s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.4;, score=0.920 total time=  37.6s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.5;, score=0.921 total time=  37.0s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.6;, score=0.921 total time=  56.7s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.6;, score=0.923 total time=  57.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.6;, score=0.933 total time=  50.0s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.7;, score=0.925 total time=  51.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.5;, score=0.918 total time=  48.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.5;, score=0.926 total time=  48.0s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.7;, score=0.927 total time=  55.4s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.6;, score=0.923 total time=  45.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=5, n_estimators=340, subsample=0.7;, score=0.923 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.4;, score=0.919 total time=  45.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.6;, score=0.926 total time=  50.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.6;, score=0.924 total time=  52.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.4;, score=0.918 total time=  44.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.7;, score=0.925 total time=  55.8s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.4;, score=0.920 total time=  45.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.6;, score=0.923 total time=  41.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.7;, score=0.925 total time=  56.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=260, subsample=0.7;, score=0.927 total time=  57.1s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.5;, score=0.922 total time=  50.8s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.5;, score=0.926 total time=  47.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.5;, score=0.919 total time=  50.4s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.4;, score=0.919 total time=  40.7s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.4;, score=0.921 total time=  40.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.4;, score=0.919 total time=  46.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.6;, score=0.924 total time=  56.1s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.7;, score=0.922 total time=  50.7s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.6;, score=0.927 total time=  54.6s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.5;, score=0.919 total time=  50.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.5;, score=0.919 total time=  52.2s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.7;, score=0.924 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.5;, score=0.926 total time=  52.0s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=280, subsample=0.7;, score=0.928 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.6;, score=0.927 total time=  52.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.6;, score=0.924 total time=  55.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.4;, score=0.918 total time=  47.0s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.7;, score=0.924 total time=  55.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.6;, score=0.923 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.4;, score=0.919 total time=  49.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.4;, score=0.920 total time=  51.0s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.5;, score=0.921 total time=  53.2s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.5;, score=0.927 total time=  52.6s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.7;, score=0.923 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=300, subsample=0.7;, score=0.928 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.6;, score=0.924 total time=  55.2s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.4;, score=0.918 total time=  45.2s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.5;, score=0.920 total time=  57.9s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.6;, score=0.926 total time=  56.0s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.6;, score=0.928 total time=  58.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.5;, score=0.922 total time=  45.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.5;, score=0.920 total time=  50.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.4;, score=0.921 total time=  53.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.4;, score=0.922 total time=  52.6s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.7;, score=0.927 total time=  59.3s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.7;, score=0.925 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=320, subsample=0.7;, score=0.924 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.4;, score=0.926 total time=  37.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.4;, score=0.914 total time=  44.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.4;, score=0.919 total time=  42.7s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.5;, score=0.930 total time=  59.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.6;, score=0.923 total time=  58.6s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.6;, score=0.925 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.5;, score=0.920 total time=  52.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.6;, score=0.929 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.7;, score=0.925 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.5;, score=0.923 total time=  52.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.5;, score=0.923 total time=  50.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.7;, score=0.923 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=6, n_estimators=340, subsample=0.7;, score=0.927 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.4;, score=0.917 total time=  49.3s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.4;, score=0.916 total time=  48.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.6;, score=0.923 total time=  58.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.6;, score=0.920 total time=  59.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.7;, score=0.929 total time=  56.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.4;, score=0.925 total time=  49.5s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.6;, score=0.926 total time=  59.7s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.7;, score=0.924 total time=  59.1s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=260, subsample=0.7;, score=0.926 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.5;, score=0.923 total time=  51.1s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.5;, score=0.922 total time=  53.2s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.5;, score=0.919 total time=  54.8s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.6;, score=0.922 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.4;, score=0.917 total time=  48.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.6;, score=0.922 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.4;, score=0.920 total time=  53.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.6;, score=0.926 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.4;, score=0.926 total time=  48.8s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.7;, score=0.925 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.7;, score=0.927 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=280, subsample=0.7;, score=0.929 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.5;, score=0.923 total time=  54.7s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6;, score=0.920 total time=  51.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.5;, score=0.920 total time=  58.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.5;, score=0.925 total time=  59.9s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.4;, score=0.918 total time=  48.7s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6;, score=0.922 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.7;, score=0.924 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.6;, score=0.926 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.4;, score=0.926 total time=  56.0s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.4;, score=0.920 total time=  56.3s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.5;, score=0.922 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.5;, score=0.919 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.7;, score=0.927 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.5;, score=0.923 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.7;, score=0.926 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=300, subsample=0.7;, score=0.929 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.6;, score=0.921 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=340, subsample=0.4;, score=0.928 total time=  50.0s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.6;, score=0.922 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.6;, score=0.924 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=340, subsample=0.4;, score=0.918 total time=  59.5s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=340, subsample=0.4;, score=0.920 total time=  58.4s
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.25, max_depth=5, n_estimators=260, subsample=0.4;, score=0.920 total time=  32.5s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.25, max_depth=5, n_estimators=260, subsample=0.4;, score=0.910 total time=  33.1s
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=340, subsample=0.5;, score=0.919 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.25, max_depth=5, n_estimators=260, subsample=0.5;, score=0.920 total time=  30.9s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.25, max_depth=5, n_estimators=260, subsample=0.4;, score=0.915 total time=  35.4s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.7;, score=0.929 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=320, subsample=0.7;, score=0.926 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=340, subsample=0.5;, score=0.922 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.25, max_depth=5, n_estimators=260, subsample=0.5;, score=0.915 total time=  39.1s
# [CV 3/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=340, subsample=0.5;, score=0.926 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.2, max_depth=7, n_estimators=340, subsample=0.6;, score=0.923 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.4, learning_rate=0.25, max_depth=5, n_estimators=260, subsample=0.6;, score=0.921 total time=  38.2s
# ...
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=5, n_estimators=340, subsample=0.7;, score=0.919 total time= 1.6min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=260, subsample=0.6;, score=0.919 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.4;, score=0.913 total time=  53.8s
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=5, n_estimators=340, subsample=0.7;, score=0.925 total time= 1.6min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.4;, score=0.915 total time=  56.9s
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=260, subsample=0.6;, score=0.919 total time= 1.4min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=260, subsample=0.6;, score=0.923 total time= 1.4min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=260, subsample=0.7;, score=0.920 total time= 1.4min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.4;, score=0.919 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=260, subsample=0.7;, score=0.924 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=260, subsample=0.7;, score=0.921 total time= 1.5min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.5;, score=0.918 total time= 1.3min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.5;, score=0.920 total time= 1.4min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.5;, score=0.923 total time= 1.3min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.4;, score=0.913 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.4;, score=0.913 total time= 1.3min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.6;, score=0.922 total time= 1.5min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.6;, score=0.921 total time= 1.5min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.4;, score=0.915 total time=  59.9s
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.4;, score=0.919 total time= 1.3min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.6;, score=0.924 total time= 1.5min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.7;, score=0.920 total time= 1.6min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.7;, score=0.920 total time= 1.6min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.5;, score=0.918 total time= 1.5min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=280, subsample=0.7;, score=0.924 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.5;, score=0.920 total time= 1.4min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.6;, score=0.922 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.5;, score=0.917 total time= 1.5min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.4;, score=0.914 total time= 1.3min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.5;, score=0.917 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.5;, score=0.919 total time= 1.3min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.7;, score=0.921 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.4;, score=0.920 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.6;, score=0.922 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.6;, score=0.925 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.7;, score=0.925 total time= 1.6min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=300, subsample=0.7;, score=0.920 total time= 1.7min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.5;, score=0.922 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.6;, score=0.923 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.6;, score=0.922 total time= 1.6min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.6;, score=0.922 total time= 1.7min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.4;, score=0.920 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.5;, score=0.922 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.7;, score=0.921 total time= 1.5min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.7;, score=0.922 total time= 1.7min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.4;, score=0.915 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.4;, score=0.914 total time= 1.4min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.4;, score=0.916 total time= 1.3min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.5;, score=0.918 total time= 1.6min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.4;, score=0.913 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.4;, score=0.918 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.5;, score=0.918 total time= 1.6min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.7;, score=0.920 total time= 1.5min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=320, subsample=0.7;, score=0.926 total time= 1.8min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.6;, score=0.923 total time= 1.6min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.7;, score=0.922 total time= 1.6min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.6;, score=0.922 total time= 1.7min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.5;, score=0.921 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.5;, score=0.919 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.6;, score=0.921 total time= 1.8min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.5;, score=0.922 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.6;, score=0.922 total time= 1.5min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.6;, score=0.922 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=6, n_estimators=340, subsample=0.7;, score=0.925 total time= 1.8min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.6;, score=0.924 total time= 1.6min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.7;, score=0.919 total time= 1.5min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.4;, score=0.917 total time= 1.3min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.4;, score=0.914 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.7;, score=0.921 total time= 1.5min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.4;, score=0.916 total time= 1.3min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.5;, score=0.920 total time= 1.3min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=260, subsample=0.7;, score=0.929 total time= 1.7min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.5;, score=0.921 total time= 1.5min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.6;, score=0.922 total time= 1.5min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.5;, score=0.924 total time= 1.5min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.7;, score=0.922 total time= 1.4min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.7;, score=0.918 total time= 1.4min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.4;, score=0.916 total time= 1.4min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.4;, score=0.917 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.4;, score=0.913 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.6;, score=0.921 total time= 1.6min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.5;, score=0.919 total time= 1.4min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.6;, score=0.925 total time= 1.7min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.5;, score=0.921 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.5;, score=0.924 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=280, subsample=0.7;, score=0.929 total time= 1.8min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.4;, score=0.914 total time= 1.4min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.6;, score=0.921 total time= 1.7min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.6;, score=0.921 total time= 1.8min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.4;, score=0.918 total time= 1.5min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.5;, score=0.920 total time= 1.3min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.5;, score=0.922 total time= 1.4min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.6;, score=0.925 total time= 1.8min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.7;, score=0.922 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.4;, score=0.918 total time= 1.5min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.7;, score=0.918 total time= 1.8min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=300, subsample=0.7;, score=0.929 total time= 1.8min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.6;, score=0.922 total time= 1.5min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.5;, score=0.923 total time= 1.7min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.7;, score=0.917 total time= 1.3min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.6;, score=0.924 total time= 1.6min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.4;, score=0.914 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.4;, score=0.918 total time= 1.3min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.4;, score=0.918 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.6;, score=0.922 total time= 1.7min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.7;, score=0.924 total time= 1.6min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.5;, score=0.924 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=320, subsample=0.7;, score=0.930 total time= 1.5min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.5;, score=0.921 total time= 1.4min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.5;, score=0.920 total time= 1.4min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.6;, score=0.922 total time= 1.3min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.6;, score=0.922 total time= 1.3min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.6;, score=0.926 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.7;, score=0.918 total time= 1.4min
# [CV 3/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.7;, score=0.930 total time= 1.3min
# [CV 2/3] END colsample_bytree=0.7, learning_rate=0.25, max_depth=7, n_estimators=340, subsample=0.7;, score=0.922 total time= 1.3min
# Best Parameters: {'colsample_bytree': 0.6, 'learning_rate': 0.2, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.7}
# Accuracy: 0.9305779786890539
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      1505
#            1       0.96      0.90      0.93      1592
#
#     accuracy                           0.93      3097
#    macro avg       0.93      0.93      0.93      3097
# weighted avg       0.93      0.93      0.93      3097

# %%
results_df = pd.DataFrame(grid_search.cv_results_)

# Display the DataFrame
#print(results_df)
results_df.head()
#results_df.to_csv('xgboost_reults.csv')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      36.382529      0.249636         0.071412        0.000406
# 1      41.124581      0.787537         0.070274        0.000736
# 2      43.772101      1.366132         0.063285        0.007612
# 3      46.101681      2.798880         0.069681        0.001688
# 4      36.925366      1.981557         0.071503        0.009834
#
#   param_colsample_bytree param_learning_rate param_max_depth  \
# 0                    0.4                0.15               5
# 1                    0.4                0.15               5
# 2                    0.4                0.15               5
# 3                    0.4                0.15               5
# 4                    0.4                0.15               5
#
#   param_n_estimators param_subsample  \
# 0                260             0.4
# 1                260             0.5
# 2                260             0.6
# 3                260             0.7
# 4                280             0.4
#
#                                               params  split0_test_score  \
# 0  {'colsample_bytree': 0.4, 'learning_rate': 0.1...           0.917656
# 1  {'colsample_bytree': 0.4, 'learning_rate': 0.1...           0.919351
# 2  {'colsample_bytree': 0.4, 'learning_rate': 0.1...           0.922015
# 3  {'colsample_bytree': 0.4, 'learning_rate': 0.1...           0.920804
# 4  {'colsample_bytree': 0.4, 'learning_rate': 0.1...           0.919109
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.920300           0.921996         0.919984        0.001786
# 1           0.919816           0.923450         0.920872        0.001832
# 2           0.921996           0.928052         0.924021        0.002850
# 3           0.919574           0.927326         0.922568        0.003402
# 4           0.921269           0.922481         0.920953        0.001395
#
#    rank_test_score
# 0              592
# 1              541
# 2              243
# 3              390
# 4              534

# %%
# GPU
#
# n_estimators: [20, 50]
# n_jobs = 3
# -> 4:23
#
# n_estimators: [20, 50]
# n_jobs = 12
# -> 



# CPU
# n_estimators: [20, 50]
# n_jobs = 26
# -> 0:19

# %%
import pandas as pd
df = pd.read_csv('xgboost_reults.csv')
df.head()
df.sort_values(by=['rank_test_score'], inplace=True)
df.head()
df.iloc[0]['params']
# Out:
# "{'colsample_bytree': 0.6, 'learning_rate': 0.2, 'max_depth': 6, 'n_estimators': 300, 'subsample': 0.7}"
